# %% [markdown]
# # Twitter data
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# # Twitter API Access
#
# Twitter implements OAuth 1.0A as its standard authentication mechanism, and in order to use it to make requests to Twitter's API, you'll need to go to https://dev.twitter.com/apps and create a sample application.
#
# Choose any name for your application, write a description and use `http://google.com` for the website.
#
# Under **Key and Access Tokens**, there are four primary identifiers you'll need to note for an OAuth 1.0A workflow:
# * consumer key,
# * consumer secret,
# * access token, and
# * access token secret (Click on Create Access Token to create those).
#
# Note that you will need an ordinary Twitter account in order to login, create an app, and get these credentials.

# %% [markdown]
# The first time you execute the notebook, add all credentials so that you can save them in the `pkl` file, then you can remove the secret keys from the notebook because they will just be loaded from the `pkl` file.
#
# The `pkl` file contains sensitive information that can be used to take control of your twitter acccount, **do not share it**.

# %%
import pickle
import os

# %%
if not os.path.exists('secret_twitter_credentials2.pkl'):
    Twitter={}
    Twitter['Consumer Key'] = ''
    Twitter['Consumer Secret'] = ''
    Twitter['Access Token'] = ''
    Twitter['Access Token Secret'] = ''
    with open('secret_twitter_credentials.pkl2','wb') as f:
        pickle.dump(Twitter, f)
else:
    Twitter=pickle.load(open('secret_twitter_credentials.pkl2','rb'))

# %% [markdown]
# Install the `twitter` package to interface with the Twitter API

# %%
# !pip install twitter
# !pip install tweepy
# Out:
# Collecting twitter
#   Using cached https://files.pythonhosted.org/packages/85/e2/f602e3f584503f03e0389491b251464f8ecfe2596ac86e6b9068fe7419d3/twitter-1.18.0-py2.py3-none-any.whl
# Installing collected packages: twitter
# Successfully installed twitter-1.18.0
# Requirement already satisfied: tweepy in /Applications/anaconda3/lib/python3.7/site-packages (3.9.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /Applications/anaconda3/lib/python3.7/site-packages (from tweepy) (2.22.0)
# Requirement already satisfied: six>=1.10.0 in /Users/stevenhansen/.local/lib/python3.7/site-packages (from tweepy) (1.15.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Applications/anaconda3/lib/python3.7/site-packages (from tweepy) (1.3.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Applications/anaconda3/lib/python3.7/site-packages (from requests[socks]>=2.11.1->tweepy) (1.24.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Applications/anaconda3/lib/python3.7/site-packages (from requests[socks]>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Applications/anaconda3/lib/python3.7/site-packages (from requests[socks]>=2.11.1->tweepy) (2019.9.11)
# Requirement already satisfied: idna<2.9,>=2.5 in /Applications/anaconda3/lib/python3.7/site-packages (from requests[socks]>=2.11.1->tweepy) (2.8)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in /Applications/anaconda3/lib/python3.7/site-packages (from requests[socks]>=2.11.1->tweepy) (1.7.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /Applications/anaconda3/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->tweepy) (3.1.0)

# %% [markdown]
# ## Example 1. Authorizing an application to access Twitter account data

# %%
import twitter

auth = twitter.oauth.OAuth(Twitter['Access Token'],
                           Twitter['Access Token Secret'],
                           Twitter['Consumer Key'],
                           Twitter['Consumer Secret'])

twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x7fef06a9b4d0>

# %%
auth

# %% [markdown]
# ## Example 2. Retrieving trends

# %% [markdown]
# Twitter identifies locations using the Yahoo! Where On Earth ID.
#
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/
#
# look at the BOSS placefinder here: https://developer.yahoo.com/boss/placefinder/

# %%
WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# %% [markdown]
# Look for the WOEID for [san-diego](http://woeid.rosselliot.co.nz/lookup/san%20diego%20%20ca)
#
# You can change it to another location.

# %%
LOCAL_WOE_ID=23424977

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)
local_trends = twitter_api.trends.place(_id=LOCAL_WOE_ID)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /Applications/anaconda3/lib/python3.7/site-packages/twitter/api.py in _handle_response(self, req, uri, arg_data, _timeout)
#     340         try:
# --> 341             handle = urllib_request.urlopen(req, **kwargs)
#     342             if handle.headers['Content-Type'] in ['image/jpeg', 'image/png']:
#
# /Applications/anaconda3/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#
# /Applications/anaconda3/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#
# /Applications/anaconda3/lib/python3.7/urllib/request.py in http_response(self, request, response)
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#
# /Applications/anaconda3/lib/python3.7/urllib/request.py in error(self, proto, *args)
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#
# /Applications/anaconda3/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#
# /Applications/anaconda3/lib/python3.7/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#
# HTTPError: HTTP Error 400: Bad Request
#
# During handling of the above exception, another exception occurred:
#
# TwitterHTTPError                          Traceback (most recent call last)
# <ipython-input-6-cbcc56ca7c58> in <module>
#       5 # to the URL itself as a special case keyword argument.
#       6
# ----> 7 world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
#       8 us_trends = twitter_api.trends.place(_id=US_WOE_ID)
#       9 local_trends = twitter_api.trends.place(_id=LOCAL_WOE_ID)
#
# /Applications/anaconda3/lib/python3.7/site-packages/twitter/api.py in __call__(self, **kwargs)
#     332             return self._handle_response_with_retry(req, uri, arg_data, _timeout)
#     333         else:
# --> 334             return self._handle_response(req, uri, arg_data, _timeout)
#     335
#     336     def _handle_response(self, req, uri, arg_data, _timeout=None):
#
# /Applications/anaconda3/lib/python3.7/site-packages/twitter/api.py in _handle_response(self, req, uri, arg_data, _timeout)
#     365                 return []
#     366             else:
# --> 367                 raise TwitterHTTPError(e, uri, self.format, arg_data)
#     368
#     369     def _handle_response_with_retry(self, req, uri, arg_data, _timeout=None):
#
# TwitterHTTPError: Twitter sent status 400 for URL: 1.1/trends/place.json using parameters: (id=1&oauth_consumer_key=&oauth_nonce=3583886503538952837&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1611266558&oauth_version=1.0&oauth_signature=UC4b9uJeIrbxWScPxH%2F%2FxTfg6%2Bs%3D)
# details: {'errors': [{'code': 215, 'message': 'Bad Authentication data.'}]}

# %%
import json
local_trends = json.dumps(local_trends[:2],indent=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-74f134650bca> in <module>
#       1 import json
# ----> 2 local_trends = json.dumps(local_trends[:2],indent=1)
#
# NameError: name 'local_trends' is not defined

# %%
help
# Out:
# Type help() for interactive help, or help(object) for help about object.

# %%
local_trends[0]['trends']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-d87a272a5ca9> in <module>
# ----> 1 local_trends[0]['trends']
#
# TypeError: string indices must be integers

# %%
trends=local_trends
#print(type(trends))
#print(list(trends[0].keys()))
print(trends[0]['trends'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-f70db2caaad2> in <module>
#       2 #print(type(trends))
#       3 #print(list(trends[0].keys()))
# ----> 4 print(trends[0]['trends'])
#
# TypeError: string indices must be integers

# %% [markdown]
# ## Example 3. Displaying API responses as pretty-printed JSON

# %%
import json

print((json.dumps(us_trends[:2], indent=1)))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "Chris Wallace",
#     "url": "http://twitter.com/search?q=%22Chris+Wallace%22",
#     "promoted_content": null,
#     "query": "%22Chris+Wallace%22",
#     "tweet_volume": 36716
#    },
#    {
#     "name": "#discorddown",
#     "url": "http://twitter.com/search?q=%23discorddown",
#     "promoted_content": null,
#     "query": "%23discorddown",
#     "tweet_volume": null
#    },
#    {
#     "name": "Gronk",
#     "url": "http://twitter.com/search?q=Gronk",
#     "promoted_content": null,
#     "query": "Gronk",
#     "tweet_volume": null
#    },
#    {
#     "name": "Cloudflare",
#     "url": "http://twitter.com/search?q=Cloudflare",
#     "promoted_content": null,
#     "query": "Cloudflare",
#     "tweet_volume": null
#    },
#    {
#     "name": "#FreeCodeFridayContest",
#     "url": "http://twitter.com/search?q=%23FreeCodeFridayContest",
#     "promoted_content": null,
#     "query": "%23FreeCodeFridayContest",
#     "tweet_volume": null
#    },
#    {
#     "name": "#TheLPShow",
#     "url": "http://twitter.com/search?q=%23TheLPShow",
#     "promoted_content": null,
#     "query": "%23TheLPShow",
#     "tweet_volume": 208180
#    },
#    {
#     "name": "Bryson",
#     "url": "http://twitter.com/search?q=Bryson",
#     "promoted_content": null,
#     "query": "Bryson",
#     "tweet_volume": null
#    },
#    {
#     "name": "#NationalTattooDay",
#     "url": "http://twitter.com/search?q=%23NationalTattooDay",
#     "promoted_content": null,
#     "query": "%23NationalTattooDay",
#     "tweet_volume": null
#    },
#    {
#     "name": "#WorldEmojiDay",
#     "url": "http://twitter.com/search?q=%23WorldEmojiDay",
#     "promoted_content": null,
#     "query": "%23WorldEmojiDay",
#     "tweet_volume": 110731
#    },
#    {
#     "name": "Leeds",
#     "url": "http://twitter.com/search?q=Leeds",
#     "promoted_content": null,
#     "query": "Leeds",
#     "tweet_volume": 178907
#    },
#    {
#     "name": "Gamer Girl",
#     "url": "http://twitter.com/search?q=%22Gamer+Girl%22",
#     "promoted_content": null,
#     "query": "%22Gamer+Girl%22",
#     "tweet_volume": 13256
#    },
#    {
#     "name": "Happy Birthday Emily",
#     "url": "http://twitter.com/search?q=%22Happy+Birthday+Emily%22",
#     "promoted_content": null,
#     "query": "%22Happy+Birthday+Emily%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Gestapo",
#     "url": "http://twitter.com/search?q=Gestapo",
#     "promoted_content": null,
#     "query": "Gestapo",
#     "tweet_volume": 182090
#    },
#    {
#     "name": "Mike Evans",
#     "url": "http://twitter.com/search?q=%22Mike+Evans%22",
#     "promoted_content": null,
#     "query": "%22Mike+Evans%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Watford",
#     "url": "http://twitter.com/search?q=Watford",
#     "promoted_content": null,
#     "query": "Watford",
#     "tweet_volume": 22324
#    },
#    {
#     "name": "Leland",
#     "url": "http://twitter.com/search?q=Leland",
#     "promoted_content": null,
#     "query": "Leland",
#     "tweet_volume": null
#    },
#    {
#     "name": "Odell",
#     "url": "http://twitter.com/search?q=Odell",
#     "promoted_content": null,
#     "query": "Odell",
#     "tweet_volume": 22150
#    },
#    {
#     "name": "Justice Ginsburg",
#     "url": "http://twitter.com/search?q=%22Justice+Ginsburg%22",
#     "promoted_content": null,
#     "query": "%22Justice+Ginsburg%22",
#     "tweet_volume": 31768
#    },
#    {
#     "name": "Toronto",
#     "url": "http://twitter.com/search?q=Toronto",
#     "promoted_content": null,
#     "query": "Toronto",
#     "tweet_volume": 75684
#    },
#    {
#     "name": "Michael Thomas",
#     "url": "http://twitter.com/search?q=%22Michael+Thomas%22",
#     "promoted_content": null,
#     "query": "%22Michael+Thomas%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Tamar",
#     "url": "http://twitter.com/search?q=Tamar",
#     "promoted_content": null,
#     "query": "Tamar",
#     "tweet_volume": 53175
#    },
#    {
#     "name": "DeChambeau",
#     "url": "http://twitter.com/search?q=DeChambeau",
#     "promoted_content": null,
#     "query": "DeChambeau",
#     "tweet_volume": null
#    },
#    {
#     "name": "Declan Rice",
#     "url": "http://twitter.com/search?q=%22Declan+Rice%22",
#     "promoted_content": null,
#     "query": "%22Declan+Rice%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Mykki",
#     "url": "http://twitter.com/search?q=Mykki",
#     "promoted_content": null,
#     "query": "Mykki",
#     "tweet_volume": null
#    },
#    {
#     "name": "Discord and Valorant",
#     "url": "http://twitter.com/search?q=%22Discord+and+Valorant%22",
#     "promoted_content": null,
#     "query": "%22Discord+and+Valorant%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Madigan",
#     "url": "http://twitter.com/search?q=Madigan",
#     "promoted_content": null,
#     "query": "Madigan",
#     "tweet_volume": null
#    },
#    {
#     "name": "DDOS",
#     "url": "http://twitter.com/search?q=DDOS",
#     "promoted_content": null,
#     "query": "DDOS",
#     "tweet_volume": null
#    },
#    {
#     "name": "Bonnie",
#     "url": "http://twitter.com/search?q=Bonnie",
#     "promoted_content": null,
#     "query": "Bonnie",
#     "tweet_volume": 18223
#    },
#    {
#     "name": "#VoteBlueToEndThisNightmare",
#     "url": "http://twitter.com/search?q=%23VoteBlueToEndThisNightmare",
#     "promoted_content": null,
#     "query": "%23VoteBlueToEndThisNightmare",
#     "tweet_volume": 20210
#    },
#    {
#     "name": "#AskOdomJr",
#     "url": "http://twitter.com/search?q=%23AskOdomJr",
#     "promoted_content": null,
#     "query": "%23AskOdomJr",
#     "tweet_volume": null
#    },
#    {
#     "name": "#NWSLChallengeCup",
#     "url": "http://twitter.com/search?q=%23NWSLChallengeCup",
#     "promoted_content": null,
#     "query": "%23NWSLChallengeCup",
#     "tweet_volume": null
#    },
#    {
#     "name": "#FridayFeeling",
#     "url": "http://twitter.com/search?q=%23FridayFeeling",
#     "promoted_content": null,
#     "query": "%23FridayFeeling",
#     "tweet_volume": 48051
#    },
#    {
#     "name": "#RBGForever",
#     "url": "http://twitter.com/search?q=%23RBGForever",
#     "promoted_content": null,
#     "query": "%23RBGForever",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ADDICTMV",
#     "url": "http://twitter.com/search?q=%23ADDICTMV",
#     "promoted_content": null,
#     "query": "%23ADDICTMV",
#     "tweet_volume": null
#    },
#    {
#     "name": "#WeirdStuffOnMyMind",
#     "url": "http://twitter.com/search?q=%23WeirdStuffOnMyMind",
#     "promoted_content": null,
#     "query": "%23WeirdStuffOnMyMind",
#     "tweet_volume": null
#    },
#    {
#     "name": "#BAONPDX",
#     "url": "http://twitter.com/search?q=%23BAONPDX",
#     "promoted_content": null,
#     "query": "%23BAONPDX",
#     "tweet_volume": null
#    },
#    {
#     "name": "#PortlandKidnappings",
#     "url": "http://twitter.com/search?q=%23PortlandKidnappings",
#     "promoted_content": null,
#     "query": "%23PortlandKidnappings",
#     "tweet_volume": null
#    },
#    {
#     "name": "#IfOneDoorCloses",
#     "url": "http://twitter.com/search?q=%23IfOneDoorCloses",
#     "promoted_content": null,
#     "query": "%23IfOneDoorCloses",
#     "tweet_volume": null
#    },
#    {
#     "name": "#GhostsofTsushima",
#     "url": "http://twitter.com/search?q=%23GhostsofTsushima",
#     "promoted_content": null,
#     "query": "%23GhostsofTsushima",
#     "tweet_volume": null
#    },
#    {
#     "name": "#JusticeForMely",
#     "url": "http://twitter.com/search?q=%23JusticeForMely",
#     "promoted_content": null,
#     "query": "%23JusticeForMely",
#     "tweet_volume": null
#    },
#    {
#     "name": "#FlashbackFriday",
#     "url": "http://twitter.com/search?q=%23FlashbackFriday",
#     "promoted_content": null,
#     "query": "%23FlashbackFriday",
#     "tweet_volume": 12805
#    },
#    {
#     "name": "#SHEAR2020",
#     "url": "http://twitter.com/search?q=%23SHEAR2020",
#     "promoted_content": null,
#     "query": "%23SHEAR2020",
#     "tweet_volume": null
#    },
#    {
#     "name": "#COYI",
#     "url": "http://twitter.com/search?q=%23COYI",
#     "promoted_content": null,
#     "query": "%23COYI",
#     "tweet_volume": null
#    },
#    {
#     "name": "#FacistTrump",
#     "url": "http://twitter.com/search?q=%23FacistTrump",
#     "promoted_content": null,
#     "query": "%23FacistTrump",
#     "tweet_volume": 21375
#    },
#    {
#     "name": "#Disneyland65",
#     "url": "http://twitter.com/search?q=%23Disneyland65",
#     "promoted_content": null,
#     "query": "%23Disneyland65",
#     "tweet_volume": null
#    },
#    {
#     "name": "#lufc",
#     "url": "http://twitter.com/search?q=%23lufc",
#     "promoted_content": null,
#     "query": "%23lufc",
#     "tweet_volume": 78016
#    },
#    {
#     "name": "#WHUWAT",
#     "url": "http://twitter.com/search?q=%23WHUWAT",
#     "promoted_content": null,
#     "query": "%23WHUWAT",
#     "tweet_volume": null
#    }
#   ],
#   "as_of": "2020-07-17T21:35:22Z",
#   "created_at": "2020-07-17T21:33:09Z",
#   "locations": [
#    {
#     "name": "United States",
#     "woeid": 23424977
#    }
#   ]
#  }
# ]

# %% [markdown]
# ## Example 4. Computing the intersection of two sets of trends

# %%
trends_set = {}
trends_set['world'] = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

trends_set['us'] = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

trends_set['san diego'] = set([trend['name'] 
                     for trend in local_trends[0]['trends']])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-dcad4b5cb3b4> in <module>
#       7
#       8 trends_set['san diego'] = set([trend['name']
# ----> 9                      for trend in local_trends[0]['trends']])
#
# TypeError: string indices must be integers

# %%
for loc in ['world','us','san diego']:
    print(('-'*10,loc))
    print((','.join(trends_set[loc])))
# Out:
# ('----------', 'world')
# #HappyGamer,Hatch Act,Atalanta,#GloriaEterna,ELLA DICE MAÑANA,Rose Garden,#JanelasPelaDemocracia,#mubb,#BocaABoca,#Bolsonaro2022,Jim Acosta,WhatsApp,#CHENOR,#TBT2020,#MinistraRubilarResponde,#ApoyoParaElDesempleoEdomex,#ローソンお抹茶バスチー,Tiago Iorc,#MacrismoExplicito,Travis Diener,#AGT,#NonBinaryDay,#15Temmuz,DEMI NO ROCK IN RIO BR,Rihanna,#TrumpIsNotWell,#RasulullahaHakaretAffedilmez,#FentySkin,José Ramón Barreto,#اعدام_نکنید,#StreamLiam,#Barismuratyağcı,ツイステのCM,#SeNaoFosseHarryPotter,#cemalcancanseven,#الاخبار_الحلوه,#IntegracionCacher,Nick Cannon,Vini Vecchi,200K DA LISA,Moderna,#FluffyFunkoPOP,#ChairoDateCuenta,#RespectBlackpink,Celis,Telegram,#AprueboRetiroDeFondos,CNCO IS BACK,Benfica,#SiestaKey
# ('----------', 'us')
# #tomatoJay,Dart Bowl,#WildNOut,Puig,#negaBeatles,Geraldo,#IMPACTonAXSTV,#NotoriousRBG,#happygamer,Rose Garden,#mubb,#NYCFC,#PortfolioDay,Kinfolk,#ORLvNYC,#teachbetter,#dinnerandamovie,Jim Acosta,#TBT2020,Golden Eagles,Center for Disease Control,#AGT,Elam,Travis Diener,#NonBinaryDay,Dragon's Dogma,#AEWDark,Donner Party,YOUR America,Rihanna,Bari Weiss,#DCStargirl,#golfchat,#hcldr,Chris Paul,Steve Watkins,#StupidMistakesEveryoneMakes,Ivanka,#NationalNudeDay,Rush,Justice Ginsburg,Mo Creek,Nick Cannon,#YPSportsChat,#FluffyFunkoPOP,Moderna,#ImproveSocialMediaIn5Words,Porsha,#BibChat,#SiestaKey
# ('----------', 'san diego')
# #tomatoJay,Dart Bowl,#WildNOut,Puig,Geraldo,#IMPACTonAXSTV,#NotoriousRBG,#happygamer,Rose Garden,#mubb,#NYCFC,#PortfolioDay,#ORLvNYC,#teachbetter,#dinnerandamovie,Jim Acosta,#NonBinaryPeoplesDay,#TBT2020,Golden Eagles,Center for Disease Control,#AGT,Elam,Travis Diener,Dragon's Dogma,#AEWDark,Donner Party,YOUR America,Manny,Rihanna,Bari Weiss,#DCStargirl,#golfchat,#hcldr,Chris Paul,Steve Watkins,#StupidMistakesEveryoneMakes,Ivanka,#NationalNudeDay,Ruth,Justice Ginsburg,Mo Creek,Rush,Nick Cannon,#YPSportsChat,#FluffyFunkoPOP,Moderna,#ImproveSocialMediaIn5Words,Porsha,#BibChat,#SiestaKey

# %%
print(( '='*10,'intersection of world and us'))
print((trends_set['world'].intersection(trends_set['us'])))

print(('='*10,'intersection of us and san-diego'))
print((trends_set['san diego'].intersection(trends_set['us'])))
# Out:
# ('==========', 'intersection of world and us')
# {'Nick Cannon', 'Jim Acosta', '#TBT2020', '#FluffyFunkoPOP', 'Moderna', '#AGT', '#mubb', 'Travis Diener', '#NonBinaryDay', 'Rose Garden', 'Rihanna', '#SiestaKey'}
# ('==========', 'intersection of us and san-diego')
# {'#tomatoJay', 'Dart Bowl', '#WildNOut', 'Puig', 'Geraldo', '#IMPACTonAXSTV', '#NotoriousRBG', '#happygamer', '#teachbetter', '#mubb', 'Rose Garden', '#PortfolioDay', '#ORLvNYC', '#dinnerandamovie', 'Jim Acosta', '#TBT2020', 'Golden Eagles', 'Center for Disease Control', '#AGT', 'Elam', 'Travis Diener', "Dragon's Dogma", '#AEWDark', '#SiestaKey', 'Donner Party', 'YOUR America', 'Rihanna', 'Bari Weiss', '#DCStargirl', '#golfchat', '#hcldr', 'Chris Paul', 'Steve Watkins', '#StupidMistakesEveryoneMakes', 'Ivanka', '#NationalNudeDay', 'Rush', 'Justice Ginsburg', 'Mo Creek', 'Nick Cannon', '#YPSportsChat', '#FluffyFunkoPOP', 'Moderna', '#ImproveSocialMediaIn5Words', 'Porsha', '#BibChat', '#NYCFC'}

# %% [markdown]
# ## Example 5. Collecting search results

# %% [markdown]
# Set the variable `q` to a trending topic,
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter

# %%
topic = '#MTVAwards' 

number = 100

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=topic, count=number)

statuses = search_results['statuses']

# %%
len(statuses)
print(statuses)
# Out:
# [{'created_at': 'Wed Jul 15 21:46:03 +0000 2020', 'id': 1283518215675457536, 'id_str': '1283518215675457536', 'text': 'RT @cxhupdates: Chloe and Halle performing at the #MTVAwards https://t.co/cZHo1RiYxU', 'truncated': False, 'entities': {'hashtags': [{'text': 'MTVAwards', 'indices': [50, 60]}], 'symbols': [], 'user_mentions': [{'screen_name': 'cxhupdates', 'name': 'Chloe x Halle Updates', 'id': 983789784182280192, 'id_str': '983789784182280192', 'indices': [3, 14]}], 'urls': [], 'media': [{'id': 1008838927623417856, 'id_str': '1008838927623417856', 'indices': [61, 84], 'media_url': 'http://pbs.twimg.com/media/DgAoXVXVQAA0LT6.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DgAoXVXVQAA0LT6.jpg', 'url': 'https://t.co/cZHo1RiYxU', 'display_url': 'pic.twitter.com/cZHo1RiYxU', 'expanded_url': 'https://twitter.com/MTV/status/1008887184684822528/video/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 1200, 'h': 675, 'resize': 'fit'}, 'small': {'w': 680, 'h': 383, 'resize': 'fit'}, 'large': {'w': 1280, 'h': 720, 'resize': 'fit'}}, 'source_status_id': 1008887184684822528, 'source_status_id_str': '1008887184684822528', 'source_user_id': 2367911, 'source_user_id_str': '2367911'}]}, 'extended_entities': {'media': [{'id': 1008838927623417856, 'id_str': '1008838927623417856', 'indices': [61, 84], 'media_url': 'http://pbs.twimg.com/media/DgAoXVXVQAA0LT6.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DgAoXVXVQAA0LT6.jpg', 'url': 'https://t.co/cZHo1RiYxU', 'display_url': 'pic.twitter.com/cZHo1RiYxU', 'expanded_url': 'https://twitter.com/MTV/status/1008887184684822528/video/1', 'type': 'video', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 1200, 'h': 675, 'resize': 'fit'}, 'small': {'w': 680, 'h': 383, 'resize': 'fit'}, 'large': {'w': 1280, 'h': 720, 'resize': 'fit'}}, 'source_status_id': 1008887184684822528, 'source_status_id_str': '1008887184684822528', 'source_user_id': 2367911, 'source_user_id_str': '2367911', 'video_info': {'aspect_ratio': [16, 9], 'duration_millis': 212345, 'variants': [{'content_type': 'application/x-mpegURL', 'url': 'https://video.twimg.com/amplify_video/1008838927623417856/pl/qFNZ76ZY2Xb0FvzB.m3u8?tag=2'}, {'bitrate': 832000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/amplify_video/1008838927623417856/vid/640x360/U0Itn-R3zjzw7U4C.mp4?tag=2'}, {'bitrate': 320000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/amplify_video/1008838927623417856/vid/320x180/VrdbgndrNzhhKTm-.mp4?tag=2'}, {'bitrate': 2176000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/amplify_video/1008838927623417856/vid/1280x720/Ipod6v-8yamlP5Q7.mp4?tag=2'}]}, 'additional_media_info': {'title': '', 'description': '', 'embeddable': True, 'monetizable': True, 'source_user': {'id': 2367911, 'id_str': '2367911', 'name': 'MTV', 'screen_name': 'MTV', 'location': 'NYC', 'description': 'Support #BlackLivesMatter and find resources below:', 'url': 'https://t.co/Whp0CySMU8', 'entities': {'url': {'urls': [{'url': 'https://t.co/Whp0CySMU8', 'expanded_url': 'http://bit.ly/ANTIRACISMRESOURCES', 'display_url': 'bit.ly/ANTIRACISMRESO…', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 15786698, 'friends_count': 31124, 'listed_count': 26949, 'created_at': 'Mon Mar 26 22:30:49 +0000 2007', 'favourites_count': 20136, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 292294, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': True, 'profile_background_color': '131516', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1278334074856312834/9Kfku0xb_normal.jpg', 'profile_image_url_https': 'https://pb ...

# %% [markdown]
# Twitter often returns duplicate results, we can filter them out checking for duplicate texts:

# %%
all_text = []
filtered_statuses = []
for s in statuses:
    if not s["text"] in all_text:
        filtered_statuses.append(s)
        all_text.append(s["text"])
statuses = filtered_statuses

# %%
len(statuses)
# Out:
# 19

# %%
[s['text'] for s in search_results['statuses']]
# Out:
# ['RT @cxhupdates: Chloe and Halle performing at the #MTVAwards https://t.co/cZHo1RiYxU',
#  'RT @MTV: YES! Girl Power!! @brielarson #MTVAwards https://t.co/QHBKbpNJe0',
#  'RT @BlackstarxMusic: AFRICAN DANCE VIDEO😂😂🤣\n🇬🇭🇸🇱🇹🇬🇳🇬🇱🇷🇹🇿🇳🇦🇰🇪🇨🇩🇨🇮🇨🇲🇲🇱\nBlackstarx - GET IT IN💥♨️😍\n\nSee full on YOUTUBE LINK  \nhttps://t.co/lU…',
#  'RT @MTV: My queens @chloexhalle slayed their performance at the #MTVAwards 😍 https://t.co/cDZ8kwmkF9',
#  'RT @cxhupdates: Chloe and Halle performing at the #MTVAwards https://t.co/cZHo1RiYxU',
#  'RT @TeenMom: "You can\'t make petty mistakes. You don\'t have that luxury anymore." 💔\n\n@MaciBookout processes the news that Ryan was arrested…',
#  'RT @cxhupdates: Chloe and Halle performing at the #MTVAwards https://t.co/cZHo1RiYxU',
#  "RT @JennaGuillaume: It's that time of year again where I remind you of the time Rachel McAdams and Ryan Gosling accepted their award like t…",
#  'RT @MTV: My queens @chloexhalle slayed their performance at the #MTVAwards 😍 https://t.co/cDZ8kwmkF9',
#  "RT @MTV: The Losers' Club? More like the WINNERS CLUB ☺️☺️The cast of #ITMovie wins Best On-Screen Team at the #MTVAwards https://t.co/lq5u…",
#  'RT @dunevillenuve: chloe and halle are angels beyoncé really did bless them #mtvawards  https://t.co/y2fDHMj3rs',
#  "Okay!, I'm Much Better Now (LOL!) https://t.co/00jbJKpKyr via @YouTube  |\n\n#Vocalists  , #DJs  ,  #MCs  #Emcees  |… https://t.co/HdLdaoMjUv",
#  'RT @RealPaulWalker: “Our brother Pablo, we hope you’re proud.” \n\nDid you catch the #FastFamily receiving the Generation Award at the #MTVAw…',
#  'RT @cxhupdates: Chloe and Halle performing at the #MTVAwards https://t.co/cZHo1RiYxU',
#  'RT @MTV: My queens @chloexhalle slayed their performance at the #MTVAwards 😍 https://t.co/cDZ8kwmkF9',
#  'RT @MTVAwards: Killer on the carpet, killer in the ring. @BeckyLynchWWE 👠🥊 \n\nLess than an hour until the #MTVAwards ❗️9p on @MTV 🙌 https://…',
#  'RT @cxhupdates: Chloe and Halle performing at the #MTVAwards https://t.co/cZHo1RiYxU',
#  'RT @cxhupdates: Chloe and Halle performing at the #MTVAwards https://t.co/cZHo1RiYxU',
#  'RT @MTVteenwolf: 🚨 ALERT 🚨 The #TeenWolf cast at the #MTVAwards over years will always be CUTE AS HECK! Catch the show Monday, June 17th at…',
#  'RT @cxhupdates: Chloe and Halle performing at the #MTVAwards https://t.co/cZHo1RiYxU',
#  'RT @MTV: My queens @chloexhalle slayed their performance at the #MTVAwards 😍 https://t.co/cDZ8kwmkF9',
#  'RT @cxhupdates: Chloe and Halle performing at the #MTVAwards https://t.co/cZHo1RiYxU',
#  'RT @MTV: Losers Club lookin’ reallllll dapper at the #MTVAwards ✨ Catch the @ITMovieOfficial cast tonight at 9/8c! | 🎥: Justin NB Francis h…',
#  'RT @MTV: My queens @chloexhalle slayed their performance at the #MTVAwards 😍 https://t.co/cDZ8kwmkF9',
#  'RT @MTV: My queens @chloexhalle slayed their performance at the #MTVAwards 😍 https://t.co/cDZ8kwmkF9',
#  'RT @cxhupdates: Chloe and Halle performing at the #MTVAwards https://t.co/cZHo1RiYxU',
#  'RT @MTV: My queens @chloexhalle slayed their performance at the #MTVAwards 😍 https://t.co/cDZ8kwmkF9',
#  'RT @michaelbay: "For one world to live, the other must die." See more of #Transformers during the #MTVAwards this Sunday. https://t.co/7t2n…',
#  'RT @michaelbay: "For one world to live, the other must die." See more of #Transformers during the #MTVAwards this Sunday. https://t.co/7t2n…',
#  '#tomdelonge #MTVAwards \nThis boy need his mtv award https://t.co/x6Qkew8Kyb',
#  'RT @MTV: My queens @chloexhalle slayed their performance at the #MTVAwards 😍 https://t.co/cDZ8kwmkF9',
#  'RT @dunevillenuve: chloe and halle are angels beyoncé really did bless them #mtvawards  https://t.co/y2fDHMj3rs',
#  'RT @MTV: My queens @chloexhalle slayed their performance at the #MTVAwards 😍 https://t.co/cDZ8kwmkF9',
#  'RT @cxhupdates: Chloe and Halle performing at the #MTVAwards https://t.co/cZHo1RiYxU',
#  '"Wit Tha Game" single  available  everywhere!!! Subscribe👉 link in bio \nStream👇\n#applemusic\n#tidal  #BETawards… https://t.co/Gk3iHVCrIZ',
#  'RT @BlackstarxMusic: AFRICAN DANCE VIDEO😂😂🤣\n🇬🇭🇸🇱🇹🇬🇳🇬🇱🇷🇹🇿🇳🇦🇰🇪🇨🇩🇨🇮🇨🇲🇲🇱\nBlackstarx - GET IT IN💥♨️😍\n\nSee full on YOUTUBE LINK  \nhttps://t.co/lU…',
#  'RT @MTV: My queens @chloexhalle slayed their performance at the #MTVAwards 😍 https://t.co/cDZ8kwmkF9',
#  'RT @MTV: ￼💫 @AlishaBoe, @tommydorfman, @madelainepetsch, and more share the hardest part about getting ready for the 2018 #MTVAwards. Catch…',
#  'Depeche Mode - Violator | The 12" Singles\nAlex Molla 🎧\n\nhttps://t.co/jOvi113vt6\n\n#depechemode #violator #12singles… https://t.co/Mrygw4e3OB',
#  'RT @PopCrave: Camilla Cabello and Zara Larsson at the #MTVAwards. https://t.co/LqeKaEvTvZ',
#  'RT @MTV: My queens @chloexhalle slayed their performance at the #MTVAwards 😍 https://t.co/cDZ8kwmkF9',
#  'RT @cxhupdates: Chloe and Halle performing at the #MTVAwards https://t.co/cZHo1RiYxU']

# %%
# Show one sample search result by slicing the list...
print(json.dumps(statuses[0], indent=1))
# Out:
# {
#  "created_at": "Wed Jul 15 21:46:03 +0000 2020",
#  "id": 1283518215675457536,
#  "id_str": "1283518215675457536",
#  "text": "RT @cxhupdates: Chloe and Halle performing at the #MTVAwards https://t.co/cZHo1RiYxU",
#  "truncated": false,
#  "entities": {
#   "hashtags": [
#    {
#     "text": "MTVAwards",
#     "indices": [
#      50,
#      60
#     ]
#    }
#   ],
#   "symbols": [],
#   "user_mentions": [
#    {
#     "screen_name": "cxhupdates",
#     "name": "Chloe x Halle Updates",
#     "id": 983789784182280192,
#     "id_str": "983789784182280192",
#     "indices": [
#      3,
#      14
#     ]
#    }
#   ],
#   "urls": [],
#   "media": [
#    {
#     "id": 1008838927623417856,
#     "id_str": "1008838927623417856",
#     "indices": [
#      61,
#      84
#     ],
#     "media_url": "http://pbs.twimg.com/media/DgAoXVXVQAA0LT6.jpg",
#     "media_url_https": "https://pbs.twimg.com/media/DgAoXVXVQAA0LT6.jpg",
#     "url": "https://t.co/cZHo1RiYxU",
#     "display_url": "pic.twitter.com/cZHo1RiYxU",
#     "expanded_url": "https://twitter.com/MTV/status/1008887184684822528/video/1",
#     "type": "photo",
#     "sizes": {
#      "thumb": {
#       "w": 150,
#       "h": 150,
#       "resize": "crop"
#      },
#      "medium": {
#       "w": 1200,
#       "h": 675,
#       "resize": "fit"
#      },
#      "small": {
#       "w": 680,
#       "h": 383,
#       "resize": "fit"
#      },
#      "large": {
#       "w": 1280,
#       "h": 720,
#       "resize": "fit"
#      }
#     },
#     "source_status_id": 1008887184684822528,
#     "source_status_id_str": "1008887184684822528",
#     "source_user_id": 2367911,
#     "source_user_id_str": "2367911"
#    }
#   ]
#  },
#  "extended_entities": {
#   "media": [
#    {
#     "id": 1008838927623417856,
#     "id_str": "1008838927623417856",
#     "indices": [
#      61,
#      84
#     ],
#     "media_url": "http://pbs.twimg.com/media/DgAoXVXVQAA0LT6.jpg",
#     "media_url_https": "https://pbs.twimg.com/media/DgAoXVXVQAA0LT6.jpg",
#     "url": "https://t.co/cZHo1RiYxU",
#     "display_url": "pic.twitter.com/cZHo1RiYxU",
#     "expanded_url": "https://twitter.com/MTV/status/1008887184684822528/video/1",
#     "type": "video",
#     "sizes": {
#      "thumb": {
#       "w": 150,
#       "h": 150,
#       "resize": "crop"
#      },
#      "medium": {
#       "w": 1200,
#       "h": 675,
#       "resize": "fit"
#      },
#      "small": {
#       "w": 680,
#       "h": 383,
#       "resize": "fit"
#      },
#      "large": {
#       "w": 1280,
#       "h": 720,
#       "resize": "fit"
#      }
#     },
#     "source_status_id": 1008887184684822528,
#     "source_status_id_str": "1008887184684822528",
#     "source_user_id": 2367911,
#     "source_user_id_str": "2367911",
#     "video_info": {
#      "aspect_ratio": [
#       16,
#       9
#      ],
#      "duration_millis": 212345,
#      "variants": [
#       {
#        "content_type": "application/x-mpegURL",
#        "url": "https://video.twimg.com/amplify_video/1008838927623417856/pl/qFNZ76ZY2Xb0FvzB.m3u8?tag=2"
#       },
#       {
#        "bitrate": 832000,
#        "content_type": "video/mp4",
#        "url": "https://video.twimg.com/amplify_video/1008838927623417856/vid/640x360/U0Itn-R3zjzw7U4C.mp4?tag=2"
#       },
#       {
#        "bitrate": 320000,
#        "content_type": "video/mp4",
#        "url": "https://video.twimg.com/amplify_video/1008838927623417856/vid/320x180/VrdbgndrNzhhKTm-.mp4?tag=2"
#       },
#       {
#        "bitrate": 2176000,
#        "content_type": "video/mp4",
#        "url": "https://video.twimg.com/amplify_video/1008838927623417856/vid/1280x720/Ipod6v-8yamlP5Q7.mp4?tag=2"
#       }
#      ]
#     },
#     "additional_media_info": {
#      "title": "",
#      "description": "",
#      "embeddable": true,
#      "monetizable": true,
#      "source_user": {
#       "id": 2367911,
#       "id_str": "2367911",
#       "name": "MTV",
#       "screen_name": "MTV",
#       "location": "NYC",
#       "description": "Support #BlackLivesMatter and find resources below:",
#       "url": "https://t.co/Whp0CySMU8",
#       "entities": {
#        "url": {
#         "urls": [
#          {
#           "url": "https://t.co/Whp0CySMU8",
#           "expanded_url": "http://bit.ly/ANTIRACISMRESOURCES",
#           "display_url": "bit.ly/ANTIRACISMRESO\u2026",
#           "indices": [
#            0,
#            23
#           ]
#          }
#         ]
#        },
#        "description": {
#         "urls": []
#        }
#       },
#       "protected": false,
#       "followers_count": 15786698,
#       "friends_count": 31124,
#       "listed_count": 26949,
#       "created_at": "Mon Mar 26 22:30:49 +0000 2007",
#       "favourites_count": 20136,
#       "utc_offset": null,
#       "time_zone": null,
#       "geo_enabled": true,
#       "verified": true,
#       "statuses_count": 292294,
#       "lang": null,
#       "contributors_enabled": false,
#       "is_translator": false,
#       "is_translation_enabled": true,
#       "profile_background_color": "131516",
#       "profile_background_image_url": "http://abs.twimg.com/images/themes/theme14/bg.gif",
#       "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme14/bg.gif",
#       "profile_background_tile": true,
#       "profile_image_url": "http://pbs.twimg.com/profile_images/1278334074856312834/9Kfku0xb_normal.jpg",
#       "profile_image_url_https": "https://pbs.twimg.com/profile_images/1278334074856312834/9Kfku0xb_normal.jpg",
#       "profile_banner_url": "https://pbs.twimg.com/profile_banners/2367911/1584395868",
#       "profile_link_color": "009999",
#       "profile_sidebar_border_color": "FFFFFF",
#       "profile_sidebar_fill_color": "EFEFEF",
#       "profile_text_color": "333333",
#       "profile_use_background_image": true,
#       "has_extended_profile": false,
#       "default_profile": false,
#       "default_profile_image": false,
#       "following": false,
#       "follow_request_sent": false,
#       "notifications": false,
#       "translator_type": "regular"
#      }
#     }
#    }
#   ]
#  },
#  "metadata": {
#   "iso_language_code": "en",
#   "result_type": "recent"
#  },
#  "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#  "in_reply_to_status_id": null,
#  "in_reply_to_status_id_str": null,
#  "in_reply_to_user_id": null,
#  "in_reply_to_user_id_str": null,
#  "in_reply_to_screen_name": null,
#  "user": {
#   "id": 1074581698031964161,
#   "id_str": "1074581698031964161",
#   "name": "\ud83c\udf08\ud83c\udf1f\u2022Z A R I\u2022\ud83c\udf1f\ud83c\udf08",
#   "screen_name": "Zari_Lula",
#   "location": "Pyeongtaek-si, Republic of Korea",
#   "description": "Black Lives Matter \u270a\ud83c\udffb\u270a\ud83c\udffc\u270a\ud83c\udffd\u270a\ud83c\udffe\u270a\ud83c\udfff #justiceforgeorgefloyd",
#   "url": "https://t.co/QxTzEZe55C",
#   "entities": {
#    "url": {
#     "urls": [
#      {
#       "url": "https://t.co/QxTzEZe55C",
#       "expanded_url": "https://www.billboard.com/bbmasvote#telescope_app",
#       "display_url": "billboard.com/bbmasvote#tele\u2026",
#       "indices": [
#        0,
#        23
#       ]
#      }
#     ]
#    },
#    "description": {
#     "urls": []
#    }
#   },
#   "protected": false,
#   "followers_count": 37,
#   "friends_count": 145,
#   "listed_count": 2,
#   "created_at": "Mon Dec 17 08:26:56 +0000 2018",
#   "favourites_count": 16785,
#   "utc_offset": null,
#   "time_zone": null,
#   "geo_enabled": false,
#   "verified": false,
#   "statuses_count": 2514,
#   "lang": null,
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "F5F8FA",
#   "profile_background_image_url": null,
#   "profile_background_image_url_https": null,
#   "profile_background_tile": false,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/1266745942595624961/jfxSTe0Z_normal.jpg",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/1266745942595624961/jfxSTe0Z_normal.jpg",
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/1074581698031964161/1590850743",
#   "profile_link_color": "1DA1F2",
#   "profile_sidebar_border_color": "C0DEED",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "profile_text_color": "333333",
#   "profile_use_background_image": true,
#   "has_extended_profile": true,
#   "default_profile": true,
#   "default_profile_image": false,
#   "following": false,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none"
#  },
#  "geo": null,
#  "coordinates": null,
#  "place": null,
#  "contributors": null,
#  "retweeted_status": {
#   "created_at": "Tue Jun 19 01:42:59 +0000 2018",
#   "id": 1008887836123295749,
#   "id_str": "1008887836123295749",
#   "text": "Chloe and Halle performing at the #MTVAwards https://t.co/cZHo1RiYxU",
#   "truncated": false,
#   "entities": {
#    "hashtags": [
#     {
#      "text": "MTVAwards",
#      "indices": [
#       34,
#       44
#      ]
#     }
#    ],
#    "symbols": [],
#    "user_mentions": [],
#    "urls": [],
#    "media": [
#     {
#      "id": 1008838927623417856,
#      "id_str": "1008838927623417856",
#      "indices": [
#       45,
#       68
#      ],
#      "media_url": "http://pbs.twimg.com/media/DgAoXVXVQAA0LT6.jpg",
#      "media_url_https": "https://pbs.twimg.com/media/DgAoXVXVQAA0LT6.jpg",
#      "url": "https://t.co/cZHo1RiYxU",
#      "display_url": "pic.twitter.com/cZHo1RiYxU",
#      "expanded_url": "https://twitter.com/MTV/status/1008887184684822528/video/1",
#      "type": "photo",
#      "sizes": {
#       "thumb": {
#        "w": 150,
#        "h": 150,
#        "resize": "crop"
#       },
#       "medium": {
#        "w": 1200,
#        "h": 675,
#        "resize": "fit"
#       },
#       "small": {
#        "w": 680,
#        "h": 383,
#        "resize": "fit"
#       },
#       "large": {
#        "w": 1280,
#        "h": 720,
#        "resize": "fit"
#       }
#      },
#      "source_status_id": 1008887184684822528,
#      "source_status_id_str": "1008887184684822528",
#      "source_user_id": 2367911,
#      "source_user_id_str": "2367911"
#     }
#    ]
#   },
#   "extended_entities": {
#    "media": [
#     {
#      "id": 1008838927623417856,
#      "id_str": "1008838927623417856",
#      "indices": [
#       45,
#       68
#      ],
#      "media_url": "http://pbs.twimg.com/media/DgAoXVXVQAA0LT6.jpg",
#      "media_url_https": "https://pbs.twimg.com/media/DgAoXVXVQAA0LT6.jpg",
#      "url": "https://t.co/cZHo1RiYxU",
#      "display_url": "pic.twitter.com/cZHo1RiYxU",
#      "expanded_url": "https://twitter.com/MTV/status/1008887184684822528/video/1",
#      "type": "video",
#      "sizes": {
#       "thumb": {
#        "w": 150,
#        "h": 150,
#        "resize": "crop"
#       },
#       "medium": {
#        "w": 1200,
#        "h": 675,
#        "resize": "fit"
#       },
#       "small": {
#        "w": 680,
#        "h": 383,
#        "resize": "fit"
#       },
#       "large": {
#        "w": 1280,
#        "h": 720,
#        "resize": "fit"
#       }
#      },
#      "source_status_id": 1008887184684822528,
#      "source_status_id_str": "1008887184684822528",
#      "source_user_id": 2367911,
#      "source_user_id_str": "2367911",
#      "video_info": {
#       "aspect_ratio": [
#        16,
#        9
#       ],
#       "duration_millis": 212345,
#       "variants": [
#        {
#         "content_type": "application/x-mpegURL",
#         "url": "https://video.twimg.com/amplify_video/1008838927623417856/pl/qFNZ76ZY2Xb0FvzB.m3u8?tag=2"
#        },
#        {
#         "bitrate": 832000,
#         "content_type": "video/mp4",
#         "url": "https://video.twimg.com/amplify_video/1008838927623417856/vid/640x360/U0Itn-R3zjzw7U4C.mp4?tag=2"
#        },
#        {
#         "bitrate": 320000,
#         "content_type": "video/mp4",
#         "url": "https://video.twimg.com/amplify_video/1008838927623417856/vid/320x180/VrdbgndrNzhhKTm-.mp4?tag=2"
#        },
#        {
#         "bitrate": 2176000,
#         "content_type": "video/mp4",
#         "url": "https://video.twimg.com/amplify_video/1008838927623417856/vid/1280x720/Ipod6v-8yamlP5Q7.mp4?tag=2"
#        }
#       ]
#      },
#      "additional_media_info": {
#       "title": "",
#       "description": "",
#       "embeddable": true,
#       "monetizable": true,
#       "source_user": {
#        "id": 2367911,
#        "id_str": "2367911",
#        "name": "MTV",
#        "screen_name": "MTV",
#        "location": "NYC",
#        "description": "Support #BlackLivesMatter and find resources below:",
#        "url": "https://t.co/Whp0CySMU8",
#        "entities": {
#         "url": {
#          "urls": [
#           {
#            "url": "https://t.co/Whp0CySMU8",
#            "expanded_url": "http://bit.ly/ANTIRACISMRESOURCES",
#            "display_url": "bit.ly/ANTIRACISMRESO\u2026",
#            "indices": [
#             0,
#             23
#            ]
#           }
#          ]
#         },
#         "description": {
#          "urls": []
#         }
#        },
#        "protected": false,
#        "followers_count": 15786698,
#        "friends_count": 31124,
#        "listed_count": 26949,
#        "created_at": "Mon Mar 26 22:30:49 +0000 2007",
#        "favourites_count": 20136,
#        "utc_offset": null,
#        "time_zone": null,
#        "geo_enabled": true,
#        "verified": true,
#        "statuses_count": 292294,
#        "lang": null,
#        "contributors_enabled": false,
#        "is_translator": false,
#        "is_translation_enabled": true,
#        "profile_background_color": "131516",
#        "profile_background_image_url": "http://abs.twimg.com/images/themes/theme14/bg.gif",
#        "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme14/bg.gif",
#        "profile_background_tile": true,
#        "profile_image_url": "http://pbs.twimg.com/profile_images/1278334074856312834/9Kfku0xb_normal.jpg",
#        "profile_image_url_https": "https://pbs.twimg.com/profile_images/1278334074856312834/9Kfku0xb_normal.jpg",
#        "profile_banner_url": "https://pbs.twimg.com/profile_banners/2367911/1584395868",
#        "profile_link_color": "009999",
#        "profile_sidebar_border_color": "FFFFFF",
#        "profile_sidebar_fill_color": "EFEFEF",
#        "profile_text_color": "333333",
#        "profile_use_background_image": true,
#        "has_extended_profile": false,
#        "default_profile": false,
#        "default_profile_image": false,
#        "following": false,
#        "follow_request_sent": false,
#        "notifications": false,
#        "translator_type": "regular"
#       }
#      }
#     }
#    ]
#   },
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 983789784182280192,
#    "id_str": "983789784182280192",
#    "name": "Chloe x Halle Updates",
#    "screen_name": "cxhupdates",
#    "location": "",
#    "description": "News and updates on @chloexhalle. UNGODLY HOUR OUT NOW",
#    "url": "https://t.co/FGM23YOabW",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "https://t.co/FGM23YOabW",
#        "expanded_url": "http://bit.ly/UngodlyHour",
#        "display_url": "bit.ly/UngodlyHour",
#        "indices": [
#         0,
#         23
#        ]
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 9198,
#    "friends_count": 12,
#    "listed_count": 13,
#    "created_at": "Tue Apr 10 19:32:17 +0000 2018",
#    "favourites_count": 1462,
#    "utc_offset": null,
#    "time_zone": null,
#    "geo_enabled": false,
#    "verified": false,
#    "statuses_count": 2605,
#    "lang": null,
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "000000",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_tile": false,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/1271087725710540801/ipqEp1Hp_normal.jpg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/1271087725710540801/ipqEp1Hp_normal.jpg",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/983789784182280192/1589717667",
#    "profile_link_color": "ABB8C2",
#    "profile_sidebar_border_color": "000000",
#    "profile_sidebar_fill_color": "000000",
#    "profile_text_color": "000000",
#    "profile_use_background_image": false,
#    "has_extended_profile": false,
#    "default_profile": false,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "retweet_count": 893,
#   "favorite_count": 2032,
#   "favorited": false,
#   "retweeted": false,
#   "possibly_sensitive": false,
#   "lang": "en"
#  },
#  "is_quote_status": false,
#  "retweet_count": 893,
#  "favorite_count": 0,
#  "favorited": false,
#  "retweeted": false,
#  "possibly_sensitive": false,
#  "lang": "en"
# }

# %%
# The result of the list comprehension is a list with only one element that
# can be accessed by its index and set to the variable t
t = statuses[0]
#[ status for status in statuses 
#          if status['id'] == 316948241264549888 ][0]

# Explore the variable t to get familiarized with the data structure...

print(t['retweet_count'])
print(t['retweeted'])
# Out:
# 893
# False

# %%
print(t['coordinates'])
# Out:
# None

# %% [markdown]
# ## Example 6. Extracting text, screen names, and hashtags from tweets

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# %%
# Explore the first 5 items for each...

print(json.dumps(status_texts[0:5], indent=1))
print(json.dumps(screen_names[0:5], indent=1)) 
print(json.dumps(hashtags[0:5], indent=1))
print(json.dumps(words[0:5], indent=1))
# Out:
# [
#  "RT @cxhupdates: Chloe and Halle performing at the #MTVAwards https://t.co/cZHo1RiYxU",
#  "RT @MTV: YES! Girl Power!! @brielarson #MTVAwards https://t.co/QHBKbpNJe0",
#  "RT @BlackstarxMusic: AFRICAN DANCE VIDEO\ud83d\ude02\ud83d\ude02\ud83e\udd23\n\ud83c\uddec\ud83c\udded\ud83c\uddf8\ud83c\uddf1\ud83c\uddf9\ud83c\uddec\ud83c\uddf3\ud83c\uddec\ud83c\uddf1\ud83c\uddf7\ud83c\uddf9\ud83c\uddff\ud83c\uddf3\ud83c\udde6\ud83c\uddf0\ud83c\uddea\ud83c\udde8\ud83c\udde9\ud83c\udde8\ud83c\uddee\ud83c\udde8\ud83c\uddf2\ud83c\uddf2\ud83c\uddf1\nBlackstarx - GET IT IN\ud83d\udca5\u2668\ufe0f\ud83d\ude0d\n\nSee full on YOUTUBE LINK  \nhttps://t.co/lU\u2026",
#  "RT @MTV: My queens @chloexhalle slayed their performance at the #MTVAwards \ud83d\ude0d https://t.co/cDZ8kwmkF9",
#  "RT @TeenMom: \"You can't make petty mistakes. You don't have that luxury anymore.\" \ud83d\udc94\n\n@MaciBookout processes the news that Ryan was arrested\u2026"
# ]
# [
#  "cxhupdates",
#  "MTV",
#  "brielarson",
#  "BlackstarxMusic",
#  "MTV"
# ]
# [
#  "MTVAwards",
#  "MTVAwards",
#  "MTVAwards",
#  "ITMovie",
#  "MTVAwards"
# ]
# [
#  "RT",
#  "@cxhupdates:",
#  "Chloe",
#  "and",
#  "Halle"
# ]

# %% [markdown]
# ## Example 7. Creating a basic frequency distribution from the words in tweets

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print(c.most_common()[:10]) # top 10
    print()
# Out:
# [('the', 21), ('RT', 15), ('#MTVAwards', 9), ('at', 8), ('and', 5), ('@MTV:', 5), ('of', 4), ('on', 3), ('that', 3), ('The', 3)]
#
# [('MTV', 6), ('cxhupdates', 1), ('brielarson', 1), ('BlackstarxMusic', 1), ('chloexhalle', 1), ('TeenMom', 1), ('MaciBookout', 1), ('JennaGuillaume', 1), ('dunevillenuve', 1), ('YouTube', 1)]
#
# [('MTVAwards', 11), ('ITMovie', 1), ('mtvawards', 1), ('Vocalists', 1), ('DJs', 1), ('MCs', 1), ('Emcees', 1), ('FastFamily', 1), ('TeenWolf', 1), ('Transformers', 1)]

# %% [markdown]
# ## Example 8. Create a prettyprint function to display tuples in a nice tabular format

# %%
def prettyprint_counts(label, list_of_tuples):
    print("\n{:^20} | {:^6}".format(label, "Count"))
    print("*"*40)
    for k,v in list_of_tuples:
        print("{:20} | {:>6}".format(k,v))

# %%
for label, data in (('Word', words), 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    
    c = Counter(data)
    prettyprint_counts(label, c.most_common()[:10])
# Out:
#         Word         | Count
# ****************************************
# the                  |     21
# RT                   |     15
# #MTVAwards           |      9
# at                   |      8
# and                  |      5
# @MTV:                |      5
# of                   |      4
# on                   |      3
# that                 |      3
# The                  |      3
#
#     Screen Name      | Count
# ****************************************
# MTV                  |      6
# cxhupdates           |      1
# brielarson           |      1
# BlackstarxMusic      |      1
# chloexhalle          |      1
# TeenMom              |      1
# MaciBookout          |      1
# JennaGuillaume       |      1
# dunevillenuve        |      1
# YouTube              |      1
#
#       Hashtag        | Count
# ****************************************
# MTVAwards            |     11
# ITMovie              |      1
# mtvawards            |      1
# Vocalists            |      1
# DJs                  |      1
# MCs                  |      1
# Emcees               |      1
# FastFamily           |      1
# TeenWolf             |      1
# Transformers         |      1

# %% [markdown]
# ## Example 9. Finding the most popular retweets

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['text'].replace("\n","\\")) 
            
            # ... for each status ...
            for status in statuses 
            
            # ... so long as the status meets this condition.
                if 'retweeted_status' in status
           ]

# %% [markdown]
# We can build another `prettyprint` function to print entire tweets with their retweet count.
#
# We also want to split the text of the tweet in up to 3 lines, if needed.

# %%
row_template = "{:^7} | {:^15} | {:50}"
def prettyprint_tweets(list_of_tuples):
    print()
    print(row_template.format("Count", "Screen Name", "Text"))
    print("*"*60)
    for count, screen_name, text in list_of_tuples:
        print(row_template.format(count, screen_name, text[:50]))
        if len(text) > 50:
            print(row_template.format("", "", text[50:100]))
            if len(text) > 100:
                print(row_template.format("", "", text[100:]))

# %%
# Slice off the first 5 from the sorted results and display each item in the tuple

prettyprint_tweets(sorted(retweets, reverse=True)[:10])
# Out:
#  Count  |   Screen Name   | Text
# ************************************************************
#  6258   |       MTV       | RT @MTV: YES! Girl Power!! @brielarson #MTVAwards
#         |                 | https://t.co/QHBKbpNJe0
#  4734   |       MTV       | RT @MTV: My queens @chloexhalle slayed their perfo
#         |                 | rmance at the #MTVAwards 😍 https://t.co/cDZ8kwmkF9
#  3260   |  dunevillenuve  | RT @dunevillenuve: chloe and halle are angels beyo
#         |                 | ncé really did bless them #mtvawards  https://t.co
#         |                 | /y2fDHMj3rs
#  2411   |       MTV       | RT @MTV: The Losers' Club? More like the WINNERS C
#         |                 | LUB ☺️☺️The cast of #ITMovie wins Best On-Screen T
#         |                 | eam at the #MTVAwards https://t.co/lq5u…
#  1682   | RealPaulWalker  | RT @RealPaulWalker: “Our brother Pablo, we hope yo
#         |                 | u’re proud.” \\Did you catch the #FastFamily recei
#         |                 | ving the Generation Award at the #MTVAw…
#  1108   |       MTV       | RT @MTV: Losers Club lookin’ reallllll dapper at t
#         |                 | he #MTVAwards ✨ Catch the @ITMovieOfficial cast to
#         |                 | night at 9/8c! | 🎥: Justin NB Francis h…
#   958   |   MTVteenwolf   | RT @MTVteenwolf: 🚨 ALERT 🚨 The #TeenWolf cast at t
#         |                 | he #MTVAwards over years will always be CUTE AS HE
#         |                 | CK! Catch the show Monday, June 17th at…
#   922   |    MTVAwards    | RT @MTVAwards: Killer on the carpet, killer in the
#         |                 |  ring. @BeckyLynchWWE 👠🥊 \\Less than an hour until
#         |                 |  the #MTVAwards ❗️9p on @MTV 🙌 https://…
#   893   |   cxhupdates    | RT @cxhupdates: Chloe and Halle performing at the
#         |                 | #MTVAwards https://t.co/cZHo1RiYxU
#   550   |   michaelbay    | RT @michaelbay: "For one world to live, the other
#         |                 | must die." See more of #Transformers during the #M
#         |                 | TVAwards this Sunday. https://t.co/7t2n…
